# %%
print("Hello World")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Hello World
# </div>

# %%
# %python 
import sys
sys.version
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">True
# sys.real_prefix /usr
# sys.base_prefix /local_disk0/pythonVirtualEnvDirs/virtualEnv-caba72fe-afcf-4483-885a-9ac10418846a
# sys.prefix /local_disk0/pythonVirtualEnvDirs/virtualEnv-caba72fe-afcf-4483-885a-9ac10418846a
# </div>

# %%
# %sh 
pwd
ls
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/driver
# conf
# derby.log
# eventlogs
# ganglia
# logs
# </div>

# %%
# %sh sudo apt-get install tree

# %%
# %sh tree /dbfs/FileStore/

# %%
# %scala
dbutils.notebook.getContext.notebookPath

# %%
dbutils.help()
dbutils.fs.ls("/FileStore")

# %%
spark.version

# %%
# %pip install art
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# ...
# Python interpreter will be restarted.
# </div>

# %%
from art import tprint

tprint("NetCoreConf")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"> _   _        _     ____                      ____                 __
#  \ | |  ___ | |_  / ___|  ___   _ __   ___  / ___|  ___   _ __   / _|
#   \| | / _ \| __|| |     / _ \ | &#39;__| / _ \| |     / _ \ | &#39;_ \ | |_
#  |\  ||  __/| |_ | |___ | (_) || |   |  __/| |___ | (_) || | | ||  _|
# _| \_| \___| \__| \____| \___/ |_|    \___| \____| \___/ |_| |_||_|
#
#
# </div>
